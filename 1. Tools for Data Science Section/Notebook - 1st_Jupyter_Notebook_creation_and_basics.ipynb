# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Lucas**
# Desired occupation: Data Scientist

# %% [markdown]
# *I am interested in Data Science because I want to shift my career to a more independant/freelance job as well as working in a field that is growing.*

# %% [markdown]
# ### The below code simply render the product of 2 and 4

# %%
2*4
# Out:
# 8

# %% [markdown]
# + List1
# + List2
# + List3
#
# | col1 | col2 | col3 |
# |---|---|---|
# |1|2|3|
#
# `this is in line code`
#
# ```python
# def python_highlight:
#     return "this is Python Highlighting"
# ```
